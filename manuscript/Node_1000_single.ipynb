# %%
import pandas as pd
import numpy as np

metric_df = pd.read_csv('metrics_1000_node_single.csv')

# %%
validation = metric_df[['epoch','val_loss']].dropna().set_index('epoch')
train = metric_df[['epoch','train_loss']].dropna().set_index('epoch')

# %%
from matplotlib.pylab import plt
from numpy import arange
 
start = 0
end = 3000
name = f'1000node_single_{start}_{end}_short'

fig_size = (15,3)
    
# Retrieve each dictionary's values
train_values = train['train_loss'][:end]
val_values = validation['val_loss'][:end]
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(start, end)


plt.figure(figsize=fig_size)
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss',marker='D', alpha=0.5, lw=0.5, ms=3)
plt.plot(epochs, val_values, label='Validation Loss',marker='^', alpha=0.5, lw=0.5, ms=3)
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
 
# Display the plot
plt.legend(loc='best')

plt.savefig("%s.png"%(name), dpi=400)
plt.show()

# %%
from matplotlib.pylab import plt
from numpy import arange
 
start = 0
end = 1000
name = f'1000node_single_{start}_{end}_short'

fig_size = (8,2)
    
# Retrieve each dictionary's values
train_values = train['train_loss'][:end]
val_values = validation['val_loss'][:end]
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(start, end)


plt.figure(figsize=fig_size)
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss',marker='D', alpha=0.5, lw=0.5, ms=3)
plt.plot(epochs, val_values, label='Validation Loss',marker='^', alpha=0.5, lw=0.5, ms=3)
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
 
# Display the plot
plt.legend(loc='best')

plt.savefig("%s.png"%(name), dpi=400)
plt.show()

# %%
from matplotlib.pylab import plt
from numpy import arange
 
start = 1000
end = 2000
name = f'1000node_single_{start}_{end}_short'

fig_size = (8,2)
    
# Retrieve each dictionary's values
train_values = train['train_loss'][start:end]
val_values = validation['val_loss'][start:end]
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(start, end)


plt.figure(figsize=fig_size)
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss',marker='D', alpha=0.5, lw=0.5, ms=3)
plt.plot(epochs, val_values, label='Validation Loss',marker='^', alpha=0.5, lw=0.5, ms=3)
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
 
# Display the plot
plt.legend(loc='best')

plt.savefig("%s.png"%(name), dpi=400)
plt.show()

# %%
from matplotlib.pylab import plt
from numpy import arange
 
start = 2000
end = 3000
name = f'1000node_single_{start}_{end}_short'

fig_size = (8,2)
    
# Retrieve each dictionary's values
train_values = train['train_loss'][start:end]
val_values = validation['val_loss'][start:end]
 
# Generate a sequence of integers to represent the epoch numbers
epochs = range(start, end)


plt.figure(figsize=fig_size)
# Plot and label the training and validation loss values
plt.plot(epochs, train_values, label='Training Loss',marker='D', alpha=0.5, lw=0.5, ms=3)
plt.plot(epochs, val_values, label='Validation Loss',marker='^', alpha=0.5, lw=0.5, ms=3)
 
# Add in a title and axes labels
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
 
 
# Display the plot
plt.legend(loc='best')

plt.savefig("%s.png"%(name), dpi=400)
plt.show()
